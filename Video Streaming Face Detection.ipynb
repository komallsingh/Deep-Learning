# %%
# !pip install yt_dlp
# Out:
# Requirement already satisfied: yt_dlp in .\AppData\Local\Programs\Python\Python313\Lib\site-packages (2026.3.17)

# %%
import cv2
import yt_dlp

# %%
URL = "https://www.youtube.com/watch?v=7jLH0Dmt-EM"
ydl_options = {
    'format' : 'best[ext=mp4]'
}
with yt_dlp.YoutubeDL(ydl_options) as ydl:
    info = ydl.extract_info(URL, download= False)
    #Get video streaming URl
    video_url = info['url']
    cap = cv2.VideoCapture(video_url)
    while True:
    #get frames from video
        ret, frame = cap.read()
        #break if video ends of fails
        if not ret:
            break
        cv2.imshow("My camera", frame)
        key = cv2.waitKey(25) & 0xFF
        if key == 27:
            break
    cap.release()
    cv2.destroyAllWindows()
# Out:
# [youtube] Extracting URL: https://www.youtube.com/watch?v=7jLH0Dmt-EM
# [youtube] 7jLH0Dmt-EM: Downloading webpage
# WARNING: [youtube] No supported JavaScript runtime could be found. Only deno is enabled by default; to use another runtime add  --js-runtimes RUNTIME[:PATH]  to your command/config. YouTube extraction without a JS runtime has been deprecated, and some formats may be missing. See  https://github.com/yt-dlp/yt-dlp/wiki/EJS  for details on installing one
# [youtube] 7jLH0Dmt-EM: Downloading android vr player API JSON
